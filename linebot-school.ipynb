# %%
from flask import Flask
app = Flask(__name__)

from flask import Flask, request, abort
from linebot import  LineBotApi, WebhookHandler
from linebot.exceptions import InvalidSignatureError, LineBotApiError
from linebot.models import *

import requests
try:
    import xml.etree.cElementTree as ET
except ImportError:
    import xml.etree.ElementTree as ET

line_bot_api = LineBotApi('Bs8fuPoaP4kaCt/0+/y6hlGq9WUHpgigncJm29y2fzOdcRfpx8b9UFBcigZc7hXtRVZ3HEXQ+N4+Eo9W+Od3lHDaV02AQCWfnXZ4HEWhegHGrOlQGH0oGByEx8DXKlYPSAKW3AMAPalncI1HIjzEKAdB04t89/1O/w1cDnyilFU=')
handler = WebhookHandler('fdabf637dace423adfa1af66708d1435')

@app.route("/callback", methods=['POST'])
def callback():
    signature = request.headers['X-Line-Signature']
    body = request.get_data(as_text=True)
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        abort(400)
    return 'OK'

@handler.add(MessageEvent, message=TextMessage)
def handle_message(event):
    mtext = event.message.text
    if mtext == '@校園資訊':
        try:
            line_bot_api.reply_message(event.reply_token, button_school_imformation())
        except:
            line_bot_api.reply_message(event.reply_token,TextSendMessage(text='發生錯誤！'))
    elif mtext == '@交大生活圈':
        try:
            line_bot_api.reply_message(event.reply_token,button_nctu_life())
        except:
            line_bot_api.reply_message(event.reply_token,TextSendMessage(text='發生錯誤！'))
    elif mtext == '@校園地圖':
        try:
            line_bot_api.reply_message(event.reply_token,button_school_map())
        except:
            line_bot_api.reply_message(event.reply_token,TextSendMessage(text='發生錯誤！'))
    elif mtext == '@健康資訊':
        try:
            line_bot_api.reply_message(event.reply_token,button_healthy_imformation())
        except:
            line_bot_api.reply_message(event.reply_token,TextSendMessage(text='發生錯誤！'))
    elif mtext == '@Q&A':
        try:
            line_bot_api.reply_message(event.reply_token,button_QA())
        except:
            line_bot_api.reply_message(event.reply_token,TextSendMessage(text='發生錯誤！'))
    elif mtext == '@近期活動':
        try:
            line_bot_api.reply_message(event.reply_token,button_recent_activities())
        except:
            line_bot_api.reply_message(event.reply_token,TextSendMessage(text='發生錯誤！'))

def button_school_imformation():
    message = TemplateSendMessage(
        alt_text = "NONE",
        template = ButtonsTemplate(
            title = "校園資訊",
            text = "請選取所需服務",
            actions = [
                MessageTemplateAction(
                    label = "行事曆",
                    text = "@行事曆"
                ),
                MessageTemplateAction(
                    label = "重要公告",
                    text = "@重要公告"
                ),
                MessageTemplateAction(
                    label = "各處室位置分機",
                    text = "@各處室位置分機"
                )
            ]
        )
    )
    return message

def button_nctu_life():
    message = TemplateSendMessage(
        alt_text = "NONE",
        template = ButtonsTemplate(
            title = "交大生活圈",
            text = "請選取所需服務",
            actions = [
                MessageTemplateAction(
                    label = "餐廳營業時間",
                    text = "@餐廳營業時間"
                ),
                MessageTemplateAction(
                    label = "小紅巴",
                    text = "@小紅巴"
                ),
                MessageTemplateAction(
                    label = "校內公車",
                    text = "@校內公車"
                ),
                MessageTemplateAction(
                    label = "Youbike",
                    text = "@Youbike"
                )
            ]
        )
    )
    return message

def button_school_map():
    message = TemplateSendMessage(
        alt_text = 'NONE',
        template = ImageCarouselTemplate(
            columns = [
                ImageCarouselColumn(
                    image_url = 'https://imgur.com/xPvJMer.jpg',
                    action = MessageTemplateAction(
                        label = "光復校區",
                        text = "@光復校區"
                    )
                ),
                ImageCarouselColumn(
                    image_url = 'https://imgur.com/naDOagx.jpg',
                    action = MessageTemplateAction(
                        label = "博愛校區",
                        text = "@博愛校區"
                    ) 
                ),
                ImageCarouselColumn(
                    image_url = 'https://imgur.com/CCEJ6Zv.jpg',
                    action = MessageTemplateAction(
                        label = "六家校區",
                        text = "@六家校區"
                    ) 
                ),
                ImageCarouselColumn(
                    image_url = 'https://imgur.com/OwdSBA7.jpg',
                    action = MessageTemplateAction(
                        label = "台北校區",
                        text = "@台北校區"
                    ) 
                ),
                ImageCarouselColumn(
                    image_url = 'https://imgur.com/FQostTN.jpg',
                    action = MessageTemplateAction(
                        label = "台南校區",
                        text = "@台南校區"
                    ) 
                )
            ]
        )
    )
    return message

def button_healthy_imformation():
    message = TemplateSendMessage(
        alt_text = "NONE",
        template = ButtonsTemplate(
            title = "健康資訊",
            text = "請選取所需服務",
            actions = [
                MessageTemplateAction(
                    label = "校內門診時間",
                    text = "@校內門診時間"
                ),
                MessageTemplateAction(
                    label = "學校附近醫療院所",
                    text = "@學校附近醫療院所"
                ),
                MessageTemplateAction(
                    label = "AED位置分布地圖",
                    text = "@AED位置分布地圖"
                ),
            ]
        )
    )
    return message

def button_QA():
    message = TemplateSendMessage(
        alt_text = 'NONE',
        template = CarouselTemplate(
            columns = [
                CarouselColumn(
                    thumbnail_image_url = 'https://imgur.com/xPvJMer.jpg',
                    title = '國際交換',
                    text = 'Q&A',
                    actions = [
                        MessageTemplateAction(
                        label = "國際交換",
                        text = "@國際交換"
                        )                
                    ]
                ),
                CarouselColumn(
                    thumbnail_image_url = 'https://imgur.com/naDOagx.jpg',
                    title = '獎學金申請',
                    text = 'Q&A',
                    actions = [
                        MessageTemplateAction(
                        label = "獎學金申請",
                        text = "@獎學金申請"
                        )                
                    ]
                ),
                CarouselColumn(
                    thumbnail_image_url = 'https://imgur.com/CCEJ6Zv.jpg',
                    title = '雙主修與輔系',
                    text = 'Q&A',
                    actions = [
                        MessageTemplateAction(
                        label = "雙主修與輔系",
                        text = "@雙主修與輔系"
                        )                
                    ]
                ),
                CarouselColumn(
                    thumbnail_image_url = 'https://imgur.com/OwdSBA7.jpg',
                    title = '校際選課',
                    text = 'Q&A',
                    actions = [
                        MessageTemplateAction(
                        label = "校際選課",
                        text = "@校際選課"
                        )                
                    ]
                ),
                CarouselColumn(
                    thumbnail_image_url = 'https://imgur.com/FQostTN.jpg',
                    title = '場地租用',
                    text = 'Q&A',
                    actions = [
                        MessageTemplateAction(
                        label = "場地租用",
                        text = "@場地租用"
                        )                
                    ]
                )
            ]
        )
    )
    return message

def button_recent_activities():
    message = TemplateSendMessage(
        alt_text = "NONE",
        template = ButtonsTemplate(
            title = "近期活動",
            text = "請選取所需服務",
            actions = [
                MessageTemplateAction(
                    label = "藝文活動",
                    text = "@藝文活動"
                ),
                MessageTemplateAction(
                    label = "演講講座",
                    text = "@演講講座"
                ),
                MessageTemplateAction(
                    label = "運動賽事",
                    text = "@運動賽事"
                ),
                MessageTemplateAction(
                    label = "科學競賽",
                    text = "@科學競賽"
                ),
            ]
        )
    )
    return message
          
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [07/Nov/2020 16:54:37] "POST /callback HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Nov/2020 16:54:45] "POST /callback HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Nov/2020 16:54:49] "POST /callback HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Nov/2020 16:54:58] "POST /callback HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Nov/2020 16:55:01] "POST /callback HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Nov/2020 16:55:10] "POST /callback HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Nov/2020 16:55:13] "POST /callback HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Nov/2020 16:55:15] "POST /callback HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Nov/2020 16:55:31] "POST /callback HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Nov/2020 16:58:46] "POST /callback HTTP/1.1" 200 -
# ...
